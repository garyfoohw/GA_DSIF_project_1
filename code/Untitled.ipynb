# %%
import pandas as pd

# %%
headers_sat=["State","tot_mean_score_2017","tot_sd_2017","erw_mean_score_2017","erw_sd_2017","math_mean_score_2017","math_sd_2017","part_2017",
        "tot_mean_score_2019","tot_sd_2019","erw_mean_score_2019","erw_sd_2019","math_mean_score_2019","math_sd_2019","part_2019",]

# %%
df=pd.read_excel("../data/sat_2017_2021.xlsx",skiprows=6,skipfooter=3,names=headers_sat)

# %%
df
# Out:
#                     State  SAT_mean_score_2017  SAT_sd_2017  \
# 0                Alabama                  1165          199
# 1                 Alaska                  1080          176
# 2                Arizona                  1116          179
# 3               Arkansas                  1208          198
# 4             California                  1055          186
# 5               Colorado                  1201          194
# 6            Connecticut                  1041          210
# 7               Delaware                   996          197
# 8   District of Columbia                   950          240
# 9                Florida                  1017          190
# 10               Georgia                  1050          177
# 11                Hawaii                  1085          173
# 12                 Idaho                  1005          182
# 13              Illinois                  1115          241
# 14               Indiana                  1074          168
# ...

# %%
headers_act=["State","comp_2017","eng_2017","math_2017","read_2017","sci_2017","part_2017",
            "comp_2019","eng_2019","math_2019","read_2019","sci_2019","part_2019",]

# %%
df=pd.read_excel("../data/act_2017_2021.xlsx",skiprows=5,skipfooter=3,names=headers_act)

# %%
df
# Out:
#                     State  comp_2017  eng_2017  math_2017  read_2017  \
# 0                Alabama        19.2      18.9       18.4       19.7
# 1                 Alaska        19.8      18.7       19.8       20.4
# 2                Arizona        19.7      18.6       19.8       20.1
# 3               Arkansas        19.4      18.9       19.0       19.7
# 4             California        22.8      22.5       22.7       23.1
# 5               Colorado        20.8      20.1       20.3       21.2
# 6            Connecticut        25.2      25.5       24.6       25.6
# 7               Delaware        24.1      24.1       23.4       24.8
# 8   District of Columbia        24.2      24.4       23.5       24.9
# 9                Florida        19.8      19.0       19.4       21.0
# 10               Georgia        21.4      21.0       20.9       22.0
# 11                Hawaii        19.0      17.8       19.2       19.2
# 12                 Idaho        22.3      21.9       21.8       23.0
# ...
